# %%
import pandas as pd
import numpy as np

dict = {'Republic of Korea':'South Korea',
       'United States of America':'United States',
       'United Kingdom of Great Britain and Northern Ireland':'United Kingdom',
       'China, Hong Kong Special Administrative Region':'Hong Kong'}

# %%
energy = pd.read_excel('Energy Indicators.xls',
                       skiprows=17, skipfooter=38,usecols=[2,3,4,5],
                      names=['Country','Energy Supply','Energy Supply per Capita','% Renewable'],
                      )
#energy.rename(columns={0:'Country',
#                       'Renewable Electricity Production':'% Renewable'},inplace=True)

energy['Country']=energy['Country'].str.replace(r'\(.*\)','') #replace ()
energy['Country']=energy['Country'].str.replace('\d+','') # replace digits

for non in energy:
    energy[non] = energy[non].replace('...','np.NaN')
#energy['Energy Supply'] *=1000000

energy['Country']= energy['Country'].map(dict)

energy
# Out:
#             Country Energy Supply Energy Supply per Capita  % Renewable
# 0               NaN           321                       10    78.669280
# 1               NaN           102                       35   100.000000
# 2               NaN          1959                       51     0.551010
# 3               NaN        np.NaN                   np.NaN     0.641026
# 4               NaN             9                      121    88.695650
# 5               NaN           642                       27    70.909090
# 6               NaN             2                      136     0.000000
# 7               NaN             8                       84     0.000000
# 8               NaN          3378                       79    24.064520
# 9               NaN           143                       48    28.236060
# 10              NaN            12                      120    14.870690
# 11              NaN          5386                      231    11.810810
# ...

# %%
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Australia             14       8831               8725      90765
# ...

# %%
    #energy
    energy = pd.read_excel('Energy Indicators.xls',
                           skiprows=17, skipfooter=38,usecols=[2,3,4,5],
                          names=['Country','Energy Supply','Energy Supply per Capita','% Renewable'],
                          )
    #energy.rename(columns={0:'Country',
    #                       'Renewable Electricity Production':'% Renewable'},inplace=True)
    
    energy.dropna()
    
    energy['Country']=energy['Country'].str.replace(r'\(.*\)','') #replace ()
    energy['Country']=energy['Country'].str.replace('\d+','') # replace digits
    energy['Country']=energy['Country'].str.strip()
    for non in energy:
        energy[non] = energy[non].replace('...','np.NaN')
    #energy['Energy Supply'] *=1000000

    energy['Country']= energy['Country'].replace({'Republic of Korea':'South Korea',
                                                  'United States of America':'United States',
                                                 'United Kingdom of Great Britain and Northern Ireland':'United Kingdom',
                                                 'China, Hong Kong Special Administrative Region':'Hong Kong'})

    
    #GDP
    GDP = pd.read_csv('world_bank.csv',skiprows=4)
    GDP['Country Name']=GDP['Country Name'].replace({"Korea, Rep.": "South Korea", 
                                                     "Iran, Islamic Rep.": "Iran",
                                                     "Hong Kong SAR, China": "Hong Kong"})
    GDP = GDP.rename(columns={'Country Name':'Country'})
    GDP = GDP.drop(GDP.iloc[:,1:50],axis=1)
    #GDP = GDP.filter(['Country','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015'])
    
    #ScimEn
    ScimEn = pd.read_excel('scimagojr-3.xlsx')
    
    
    df_SE = pd.merge(ScimEn, energy, how='inner',left_on='Country',right_on='Country')
    df_SEG = pd.merge(df_SE, GDP, how='inner',left_on='Country',right_on='Country').set_index('Country')
    df=df_SEG[:15]
    df
    
#     df_SE_outer = pd.merge(ScimEn, energy, how='outer',left_on='Country',right_on='Country')
#     df_SEG_outer = pd.merge(df_SE_outer, GDP, how='outer',left_on='Country',right_on='Country').set_index('Country')
#     #outer = len(pd.concat([ScimEn['Country'],energy['Country'],GDP['Country']]).unique())
#     len(df_SEG_outer)
#     dif=len(df_SEG_outer)-len(df_SEG)
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
df['% Renewable'].max()
#sort_values(ascending = False)
#df.index[0]
df.iloc[0,9]
# Out:
# 19.75491

# %%
df_3=df.iloc[:,10:]
avgGDP = df_3.mean(axis=1).sort_values(ascending=False)
avgGDP
# Out:
# Country
# United States         1.536434e+13
# China                 6.348609e+12
# Japan                 5.542208e+12
# Germany               3.493025e+12
# France                2.681725e+12
# United Kingdom        2.487907e+12
# Brazil                2.189794e+12
# Italy                 2.120175e+12
# India                 1.769297e+12
# Canada                1.660647e+12
# Russian Federation    1.565459e+12
# Spain                 1.418078e+12
# Australia             1.164043e+12
# South Korea           1.106715e+12
# Iran                  4.441558e+11
# dtype: float64

# %%
#     num_outer = len(pd.concat([ScimEn['Country'],energy['Country'],GDP['Country']]).unique())
    
#     num_inter = (GDP.merge(energy, left_on='Country', right_on='Country', how='inner').merge(ScimEn, left_on='Country', right_on='Country', how='inner').shape[0])
    
#     print(num_outer-num_inter)
# Out:
# 161

# %%
country=avgGDP.index[5]
df.loc[country]['2015']
#df.loc[country]['2015']
# Out:
# 2666333396477.13

# %%
avgGDP.apply(lambda x:format(x,','))
# Out:
# Country
# United States           15,364,344,302,990.0
# China                    6,348,608,932,836.1
# Japan                  5,542,207,638,235.176
# Germany                3,493,025,339,072.848
# France                 2,681,724,635,761.589
# United Kingdom        2,487,906,661,418.4175
# Brazil                2,189,794,143,774.9048
# Italy                 2,120,175,089,933.7761
# India                 1,769,297,396,603.8599
# Canada                 1,660,647,466,307.512
# Russian Federation     1,565,459,478,480.661
# Spain                  1,418,078,278,145.694
# Australia              1,164,042,729,991.427
# South Korea            1,106,714,508,244.852
# Iran                   444,155,754,051.09503
# dtype: object
