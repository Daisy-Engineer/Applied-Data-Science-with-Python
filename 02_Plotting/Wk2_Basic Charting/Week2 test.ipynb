# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
plt.plot(3,2,'o-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

fig = Figure()
canvas = FigureCanvasAgg(fig)
ax = fig.add_subplot(111)

ax.plot(3,2,'.')
canvas.print_png('test.png')

# %%html
<img src = 'test.png'/>
# Out:
#   File "<ipython-input-9-855447cad633>", line 12
#     <img src = 'test.png'/>
#     ^
# SyntaxError: invalid syntax

# %%
plt.figure()
plt.plot(3, 2, 'o')
ax = plt.gca()
ax.axis=([0,6,0,10])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(1.5,1.5,'o')
plt.plot(2,2,'o')
plt.plot(2.5,2.5,'o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax=plt.gca()
ax.get_children()
# Out:
# [<matplotlib.lines.Line2D at 0x231809c75c0>,
#  <matplotlib.lines.Line2D at 0x231809b2278>,
#  <matplotlib.lines.Line2D at 0x23180988978>,
#  <matplotlib.spines.Spine at 0x231ff9097f0>,
#  <matplotlib.spines.Spine at 0x2318099e2b0>,
#  <matplotlib.spines.Spine at 0x2318099e198>,
#  <matplotlib.spines.Spine at 0x23180a1ccc0>,
#  <matplotlib.axis.XAxis at 0x231809b2eb8>,
#  <matplotlib.axis.YAxis at 0x231808ee278>,
#  Text(0.5, 1.0, ''),
#  Text(0.0, 1.0, ''),
#  Text(1.0, 1.0, ''),
#  <matplotlib.patches.Rectangle at 0x231809e14e0>]

# %%
import numpy as np

x = np.array([1,2,3,4,5,6,7,8])
y=x

plt.figure()
plt.scatter(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = np.array([1,2,3,4,5,6,7,8])
y=x

plt.figure()
plt.scatter(x,y)

colors = (len(x)-1)*['green']
colors.append('red')

plt.figure()
plt.scatter(x,y,s=100,c=colors)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
plt.xlabel('x')
plt.ylabel('y')
plt.title('Relationship')
# Out:
# Text(0.5, 1.0, 'Relationship')

# %%
plt.legend()
# Out:
# No handles with labels found to put in legend.
